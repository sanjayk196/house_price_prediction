# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('vif_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  No of Bedrooms  No of Bathrooms  Lot Area (in Sqft)  \
# 0           0               3             1.00              5650.0
# 1           1               3             2.25              7242.0
# 2           2               2             1.00             10000.0
# 3           3               4             3.00              5000.0
# 4           4               3             2.00              8080.0
#
#    No of Floors  No_of_Times_Visited  Condition_of_the_House  Overall Grade  \
# 0           1.0                    0                       2              7
# 1           2.0                    0                       2              7
# 2           1.0                    0                       2              6
# 3           1.0                    0                       3              7
# 4           1.0                    0                       2              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# 0                                     1180.0                        0  ...
# 1                                     2170.0                      400  ...
# 2                                      770.0                        0  ...
# 3                                     1050.0                      910  ...
# 4                                     1680.0                        0  ...
#
#    Zipcode_table_Zipcode_2  Zipcode_table_Zipcode_3  Zipcode_table_Zipcode_4  \
# 0                        1                        0                        0
# 1                        0                        0                        1
# 2                        0                        0                        1
# 3                        0                        0                        0
# 4                        0                        0                        0
#
#    Zipcode_table_Zipcode_5  Zipcode_table_Zipcode_6  Zipcode_table_Zipcode_7  \
# 0                        0                        0                        0
# 1                        0                        0                        0
# 2                        0                        0                        0
# 3                        0                        1                        0
# 4                        0                        0                        0
#
#    Zipcode_table_Zipcode_8  Zipcode_table_Zipcode_9  Zipcode_table_Zipcode_10  \
# 0                        0                        0                         0
# 1                        0                        0                         0
# 2                        0                        0                         0
# 3                        0                        0                         0
# 4                        1                        0                         0
#
#    sale_price
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
#
# [5 rows x 27 columns]

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['No of Bedrooms', 'No of Bathrooms', 'Lot Area (in Sqft)',
#        'No of Floors', 'No_of_Times_Visited', 'Condition_of_the_House',
#        'Overall Grade', 'Area of the House from Basement (in Sqft)',
#        'Basement Area (in Sqft)', 'Age of House (in Years)', 'Renovated Year',
#        'Longitude', 'Living Area after Renovation (in Sqft)',
#        'Lot Area after Renovation (in Sqft)', 'no_of_years(house sold)',
#        'house_is', 'Zipcode_table_Zipcode_2', 'Zipcode_table_Zipcode_3',
#        'Zipcode_table_Zipcode_4', 'Zipcode_table_Zipcode_5',
#        'Zipcode_table_Zipcode_6', 'Zipcode_table_Zipcode_7',
#        'Zipcode_table_Zipcode_8', 'Zipcode_table_Zipcode_9',
#        'Zipcode_table_Zipcode_10', 'sale_price'],
#       dtype='object')

# %%
x = df.drop(['sale_price'],axis=1)
y = df['sale_price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=101)

# %%
x_train.shape, x_test.shape, y_train.shape , y_test.shape
# Out:
# ((17287, 25), (4322, 25), (17287,), (4322,))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()

# %%
scale = StandardScaler()

# %%
x_train = scale.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.67849763,  0.17628744, -0.13672473, ..., -0.33539701,
#         -0.20695513,  5.7824091 ],
#        [-0.39757471,  0.50121344, -0.31713296, ..., -0.33539701,
#         -0.20695513, -0.1729383 ],
#        [ 1.75456997,  0.50121344, -0.25619645, ..., -0.33539701,
#         -0.20695513, -0.1729383 ],
#        ...,
#        [-0.39757471, -1.44834258, -0.16884539, ..., -0.33539701,
#         -0.20695513, -0.1729383 ],
#        [ 0.67849763, -0.47356457, -0.14920685, ..., -0.33539701,
#         -0.20695513, -0.1729383 ],
#        [ 0.67849763,  0.17628744, -0.19200269, ..., -0.33539701,
#          4.83196516, -0.1729383 ]])

# %%
x_test = scale.fit_transform(x_test)

# %%
x_test
# Out:
# array([[ 0.66938228,  0.49679891, -0.22877615, ..., -0.34428189,
#         -0.21737023, -0.18764216],
#        [ 0.66938228, -0.15022983, -0.1519448 , ..., -0.34428189,
#         -0.21737023, -0.18764216],
#        [ 0.66938228,  0.49679891, -0.25282142, ..., -0.34428189,
#          4.60044591, -0.18764216],
#        ...,
#        [ 0.66938228,  0.49679891, -0.11156836, ..., -0.34428189,
#         -0.21737023,  5.32929269],
#        [-0.40331709,  0.49679891,  0.30777908, ..., -0.34428189,
#         -0.21737023, -0.18764216],
#        [-0.40331709,  0.17328454, -0.33625747, ..., -0.34428189,
#         -0.21737023, -0.18764216]])

# %% [markdown]
# # Ridge_model

# %%
from sklearn.linear_model import Ridge

# %%
r = Ridge(normalize=True)

# %%
r.fit(x_train,y_train)
# Out:
# Ridge(normalize=True)

# %%
prediction = r.predict(x_test)

# %%
r.score(x_test,y_test)
# Out:
# 0.6906977256982989

# %%
r.coef_
# Out:
# array([  7902.04475129,  15959.10496777,   4969.9278911 ,   9944.82305511,
#         13873.08120259,   7726.73987545,  32362.83907852,  23200.59390455,
#         13953.11744433,  10714.79388031,   5532.34166588,  -4111.85145351,
#         24028.99854364,   2083.67167644,   3153.99797721,   3178.99296425,
#        -25160.530542  , -10817.69987419,  -3149.36589991,   1892.84141198,
#         18074.05597852,  18999.58145405,  22245.96155958,  16596.14252394,
#         17161.68700057])

# %% [markdown]
# ## metrics

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
r2_score = r2_score(y_test,prediction)
mae = mean_absolute_error(y_test,prediction)
mse = mean_squared_error(y_test,prediction)
rmse = mse ** 0.5

# %%
print(f'r2_score : {r2_score}')
print(f'mae : {mae}')
print(f'mse : {mse}')
print(f'rmse : {rmse}')
# Out:
# r2_score : 0.6906977256982989
# mae : 90090.93560375512
# mse : 12214228856.83952
# rmse : 110518.00241064584

# %%
prediction.shape, y_test.shape
# Out:
# ((4322,), (4322,))

# %%
table = pd.DataFrame({'y_test':y_test,'prediction':prediction})

# %%
plt.figure(figsize=(6,12),dpi=100)
sns.lmplot('y_test','prediction',data=table)

# %% [markdown]
# # residuals

# %%
residual = prediction - y_test

residual_table = pd.DataFrame({'residuals' : residual,'predictions' : prediction})
residual_table = residual_table.sort_values(by='predictions')

# %%
residual_table.head()
# Out:
#           residuals    predictions
# 19450 -40074.902361  101925.097639
# 1147   50009.790039  125009.790039
# 19342  43094.252626  194094.252626
# 18057 -77713.831094  197286.168906
# 1064   67007.444331  207007.444331

# %%
z = [i for i in range(int(residual_table['predictions'].max()))]
k = [0 for i in range(int(residual_table['predictions'].max()))]

# %%
plt.figure(figsize=(17,7),dpi=100)
plt.scatter(residual_table['predictions'],residual_table['residuals'],color='blue',s=4)
plt.plot(z,k,color='red',linewidth=3)
plt.ylim(800000,-800000)
# Out:
# (800000.0, -800000.0)

# %% [markdown]
# # distribution of errors

# %%
plt.figure(figsize=(5,5),dpi=100)
plt.hist(residual_table['residuals'],color='red',bins=150)
plt.show()

# %%
coeff_table = pd.DataFrame({'columns':['No of Bedrooms', 'No of Bathrooms', 'Lot Area (in Sqft)',
       'No of Floors', 'No_of_Times_Visited', 'Condition_of_the_House',
       'Overall Grade', 'Area of the House from Basement (in Sqft)',
       'Basement Area (in Sqft)', 'Age of House (in Years)', 'Renovated Year',
       'Longitude', 'Living Area after Renovation (in Sqft)',
       'Lot Area after Renovation (in Sqft)', 'no_of_years(house sold)',
       'house_is', 'Zipcode_table_Zipcode_2', 'Zipcode_table_Zipcode_3',
       'Zipcode_table_Zipcode_4', 'Zipcode_table_Zipcode_5',
       'Zipcode_table_Zipcode_6', 'Zipcode_table_Zipcode_7',
       'Zipcode_table_Zipcode_8', 'Zipcode_table_Zipcode_9',
       'Zipcode_table_Zipcode_10'], 'coefficients':r.coef_})
coeff_table = coeff_table.sort_values(by='coefficients')

# %%
coeff_table.head()
# Out:
#                     columns  coefficients
# 16  Zipcode_table_Zipcode_2 -25160.530542
# 17  Zipcode_table_Zipcode_3 -10817.699874
# 11                Longitude  -4111.851454
# 18  Zipcode_table_Zipcode_4  -3149.365900
# 19  Zipcode_table_Zipcode_5   1892.841412

# %%
plt.figure(figsize=(12,12),dpi=100)
plt.barh(coeff_table['columns'],coeff_table['coefficients'])
# Out:
# <BarContainer object of 25 artists>
